# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# The original scraping and DataFrame creation code
url = 'https://serebii.net/pokedex-sv/dragon.shtml'
html_contents = requests.get(url).text
soup = BeautifulSoup(html_contents, 'lxml')
# Extract the table and clean data as you did previously
dextable = soup.find("table", attrs={"class": "dextable"})
dextable_rows = dextable.find_all("td")
for td in soup.find_all():
    if len(td.get_text(strip=True)) == 0:
        td.extract()
            
headings = []
for td in soup.find_all("td"):
    headings.append(td.text.replace('\n', ' ').strip())

data = headings[9:]
data.remove('Pic')
data.remove('Base Stats')
data.remove('Type')
h = len(data)
l = int(h / 9)
df = pd.DataFrame(np.array(data).reshape(l, 9))
# Set headers
df.columns = df.iloc[0]
df = df[1:]
df
# Out:
# 0     No.          Name                                 Abilities   HP  Att  \
# 1   #0103     Exeggutor                             Frisk Harvest   95  105
# 2   #0147       Dratini                    Shed Skin Marvel Scale   41   64
# 3   #0148     Dragonair                    Shed Skin Marvel Scale   61   84
# 4   #0149     Dragonite                    Inner Focus Multiscale   91  134
# 5   #0230       Kingdra                    Swift Swim Sniper Damp   75   95
# ..    ...           ...                                       ...  ...  ...
# 65  #1011       Dipplin     Supersweet Syrup Gluttony Sticky Hold   80   80
# 66  #1018    Archaludon                   Stamina Sturdy Stalwart   90  105
# 67  #1019     Hydrapple  Supersweet Syrup Regenerator Sticky Hold  106   80
# 68  #1020  Gouging Fire                            Protosynthesis  105  115
# 69  #1021   Raging Bolt                            Protosynthesis  125   73
#
# 0   Def S.Att S.Def Spd
# 1    85   125    75  45
# 2    45    50    50  50
# 3    65    70    70  70
# 4    95   100   100  80
# 5    95    95    95  85
# ..  ...   ...   ...  ..
# 65  110    95    80  40
# 66  130   125    65  85
# 67  110   120    80  44
# 68  121    65    93  91
# 69   91   137    89  75
#
# [69 rows x 9 columns]
